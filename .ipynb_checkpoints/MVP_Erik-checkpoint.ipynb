# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
pd.set_option('display.max_columns', None) #settings to display all the columns

# %% [markdown]
# ## Reading in the data

# %%
datasets_path = './project_dataset'

datasets = os.listdir(datasets_path)

datasets

# listing datasets inside the datsets folder
# Out:
# ['extract - cash request - data analyst.csv',
#  'extract - fees - data analyst - .csv',
#  'Lexique - Data Analyst.xlsx']

# %%
# imports all all available datasets into a dictionary

df_dict = {}

for dataset in datasets:
    # if condition to read in both excel & csv
    if dataset.split('.')[-1] == 'csv':
        dataset_path = os.path.join(datasets_path, dataset)
        df_dict[dataset] = pd.read_csv(dataset_path)
    else:
        dataset_path = os.path.join(datasets_path, dataset)
        df_dict[dataset] = pd.read_excel(dataset_path)

# %%
list(df_dict.keys())

# checking the keys to conform files were read in correctly
# Out:
# ['extract - cash request - data analyst.csv',
#  'extract - fees - data analyst - .csv',
#  'Lexique - Data Analyst.xlsx']

# %%
rename_map = {
    'extract - cash request - data analyst.csv' : 'cash request',
    'extract - fees - data analyst - .csv' : 'fees',
    'Lexique - Data Analyst.xlsx' : 'lexique'
}

# %%
for old_key, new_key in rename_map.items():
    df_dict[new_key] = df_dict.pop(old_key)

# replacing the long keys with shoeter ones

# %%
df_dict.keys() # df keys are shortened
# Out:
# dict_keys(['cash request', 'fees', 'lexique'])

# %% [markdown]
# ## Initial Cash Request Exploration

# %%
df_dict['cash request'].head()
# Out:
#      id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3  2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# 2                 NaN  2020-01-09 19:13:35.825041+00
# 3                 NaN  2020-01-09 19:16:10.879606+00
# 4                 NaN         2020-06-05 22:00:00+00
#
#   cash_request_received_date money_back_date transfer_type send_at  \
# 0                        NaN             NaN       regular     NaN
# 1                        NaN             NaN       regular     NaN
# 2                        NaN             NaN       regular     NaN
# 3                        NaN             NaN       regular     NaN
# 4                        NaN             NaN       regular     NaN
#
#   recovery_status reco_creation reco_last_update
# 0             NaN           NaN              NaN
# 1             NaN           NaN              NaN
# 2             NaN           NaN              NaN
# 3             NaN           NaN              NaN
# 4             NaN           NaN              NaN

# %%
df_dict['cash request'].tail()
# Out:
#           id  amount             status                     created_at  \
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id moderated_at  \
# 23965  2021-02-06 20:17:49.292493+00  13681.0          NaN
# 23966  2020-12-18 13:15:40.843946+00      NaN          NaN
# 23967  2021-02-05 12:19:30.656816+00  82122.0          NaN
# 23968  2021-02-05 13:14:19.707627+00  64517.0          NaN
# 23969  2021-01-05 15:45:52.645536+00  44867.0          NaN
#
#        deleted_account_id      reimbursement_date cash_request_received_date  \
# 23965                 NaN  2021-02-06 11:00:00+00                 2020-10-13
# 23966             30367.0  2020-11-03 22:00:00+00                 2020-10-28
# 23967                 NaN  2021-02-05 11:00:00+00                 2020-10-21
# 23968                 NaN  2021-02-05 11:00:00+00                 2020-10-12
# 23969                 NaN  2021-02-05 11:00:00+00                 2020-10-10
#
#                      money_back_date transfer_type  \
# 23965  2021-02-06 20:17:49.257521+00       instant
# 23966  2020-12-01 13:26:53.787672+00       instant
# 23967  2021-02-05 12:19:30.626289+00       instant
# 23968  2021-02-05 13:14:19.689906+00       instant
# 23969                            NaN       instant
#
#                              send_at recovery_status  \
# 23965  2020-10-12 13:54:24.352856+00             NaN
# 23966  2020-10-27 14:41:57.901946+00       completed
# 23967  2020-10-20 07:58:14.171553+00             NaN
# 23968  2020-10-10 05:41:23.368363+00             NaN
# 23969  2020-10-08 14:17:04.526139+00             NaN
#
#                        reco_creation               reco_last_update
# 23965                            NaN                            NaN
# 23966  2020-11-12 23:20:41.928788+00  2020-12-01 13:26:53.815504+00
# 23967                            NaN                            NaN
# 23968                            NaN                            NaN
# 23969                            NaN                            NaN

# %%
df_dict['cash request'].info()

# ids are floats not int
# date columns are not date time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23970 non-null  int64
#  1   amount                      23970 non-null  float64
#  2   status                      23970 non-null  object
#  3   created_at                  23970 non-null  object
#  4   updated_at                  23970 non-null  object
#  5   user_id                     21867 non-null  float64
#  6   moderated_at                16035 non-null  object
#  7   deleted_account_id          2104 non-null   float64
#  8   reimbursement_date          23970 non-null  object
#  9   cash_request_received_date  16289 non-null  object
#  10  money_back_date             16543 non-null  object
#  11  transfer_type               23970 non-null  object
#  12  send_at                     16641 non-null  object
#  13  recovery_status             3330 non-null   object
#  14  reco_creation               3330 non-null   object
#  15  reco_last_update            3330 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 2.9+ MB

# %%
df_dict['cash request'].isna().sum()

# key issue - missing user id
# other values missing might be expected
# Out:
# id                                0
# amount                            0
# status                            0
# created_at                        0
# updated_at                        0
# user_id                        2103
# moderated_at                   7935
# deleted_account_id            21866
# reimbursement_date                0
# cash_request_received_date     7681
# money_back_date                7427
# transfer_type                     0
# send_at                        7329
# recovery_status               20640
# reco_creation                 20640
# reco_last_update              20640
# dtype: int64

# %%
print('Duplicated rows in df as a whole')
print(f'{df_dict['cash request'].duplicated().sum()}')
print() # short line brake
print('Duplicated rows per column')
for col in ['id', 'user_id']:
    print(f'{col}: {df_dict['cash request'][col].duplicated().sum()}')
# Out:
# Duplicated rows in df as a whole
# 0
#
# Duplicated rows per column
# id: 0
# user_id: 13171

# %%
sns.histplot(df_dict['cash request']['amount'])
plt.show()

# 100, 50 and 25 are the most common cash request amounts respectivaely

# %% [markdown]
# ## Cash request Data CLeaning

# %%
df_dict['cash request'].head(3)
# Out:
#    id  amount    status                     created_at  \
# 0   5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1  70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2   7   100.0  rejected   2019-12-10 19:13:35.82546+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# 2                 NaN  2020-01-09 19:13:35.825041+00
#
#   cash_request_received_date money_back_date transfer_type send_at  \
# 0                        NaN             NaN       regular     NaN
# 1                        NaN             NaN       regular     NaN
# 2                        NaN             NaN       regular     NaN
#
#   recovery_status reco_creation reco_last_update
# 0             NaN           NaN              NaN
# 1             NaN           NaN              NaN
# 2             NaN           NaN              NaN

# %%
df_dict['cash request'].columns
# Out:
# Index(['id', 'amount', 'status', 'created_at', 'updated_at', 'user_id',
#        'moderated_at', 'deleted_account_id', 'reimbursement_date',
#        'cash_request_received_date', 'money_back_date', 'transfer_type',
#        'send_at', 'recovery_status', 'reco_creation', 'reco_last_update'],
#       dtype='object')

# %%
col_dates = ['created_at', 'updated_at', 'moderated_at', 'reimbursement_date', 
            'cash_request_received_date', 'money_back_date', 'send_at',
            'reco_creation', 'reco_last_update'] # selecting only date time related columns

for col in col_dates:
    df_dict['cash request'][col] = pd.to_datetime(df_dict['cash request'][col], errors='coerce')

# %%
df_dict['cash request'].dtypes # dates casted
# Out:
# id                                          int64
# amount                                    float64
# status                                     object
# created_at                    datetime64[ns, UTC]
# updated_at                    datetime64[ns, UTC]
# user_id                                   float64
# moderated_at                  datetime64[ns, UTC]
# deleted_account_id                        float64
# reimbursement_date            datetime64[ns, UTC]
# cash_request_received_date         datetime64[ns]
# money_back_date               datetime64[ns, UTC]
# transfer_type                              object
# send_at                       datetime64[ns, UTC]
# recovery_status                            object
# reco_creation                 datetime64[ns, UTC]
# reco_last_update              datetime64[ns, UTC]
# dtype: object

# %%
# cast ids to int

for col in ['id', 'user_id', 'deleted_account_id']:
    df_dict['cash request'][col] = df_dict['cash request'][col].astype('Int64') # regular int cannot store NaN & Int64 can

# %%
df_dict['cash request'].dtypes 
#ids casted
# Out:
# id                                          Int64
# amount                                    float64
# status                                     object
# created_at                    datetime64[ns, UTC]
# updated_at                    datetime64[ns, UTC]
# user_id                                     Int64
# moderated_at                  datetime64[ns, UTC]
# deleted_account_id                          Int64
# reimbursement_date            datetime64[ns, UTC]
# cash_request_received_date         datetime64[ns]
# money_back_date               datetime64[ns, UTC]
# transfer_type                              object
# send_at                       datetime64[ns, UTC]
# recovery_status                            object
# reco_creation                 datetime64[ns, UTC]
# reco_last_update              datetime64[ns, UTC]
# dtype: object

# %%
df_dict['cash request']['created_at'].describe()

# data time frame: 2019-11-19 - 2020-11-01
# Out:
# count                                  23970
# mean     2020-08-18 01:09:13.882328576+00:00
# min         2019-11-19 13:57:53.511561+00:00
# 25%      2020-07-10 06:58:41.013899008+00:00
# 50%      2020-09-02 10:43:39.634614528+00:00
# 75%      2020-10-12 13:14:42.661127168+00:00
# max         2020-11-01 23:42:30.847066+00:00
# Name: created_at, dtype: object

# %%
df_dict['cash request'] \
    .loc[df_dict['cash request']['user_id'].isna(), ['user_id', 'deleted_account_id']] \
    .isna() \
    .sum()

# whenever uer_id is missing, deleted account id is present
# Out:
# user_id               2103
# deleted_account_id       0
# dtype: int64

# %%
df_dict['cash request']['any_user_id'] = \
    df_dict['cash request']['user_id'] \
        .fillna(df_dict['cash request']['deleted_account_id'])

# creating any id column with deleted_account_id if user id is missing

# %%
df_dict['cash request'].sample(5)
# Out:
#           id  amount      status                       created_at  \
# 22228  14689    50.0  money_back 2020-09-05 11:29:04.285876+00:00
# 3885   18877    50.0    rejected 2020-10-02 12:27:49.687368+00:00
# 20867  25051    25.0  money_back 2020-10-27 10:17:51.014389+00:00
# 23284  26936   100.0  money_back 2020-11-01 14:03:09.821066+00:00
# 18817  25382    50.0  money_back 2020-10-27 19:47:27.568897+00:00
#
#                             updated_at  user_id  \
# 22228 2020-12-18 13:13:27.703644+00:00    37283
# 3885  2020-10-02 14:45:59.949736+00:00    12328
# 20867 2020-12-18 13:12:40.661950+00:00    33543
# 23284 2020-12-18 13:14:39.427261+00:00    37278
# 18817 2020-12-18 13:11:52.552560+00:00    95740
#
#                           moderated_at  deleted_account_id  \
# 22228 2020-09-05 16:31:51.972062+00:00                <NA>
# 3885  2020-10-02 14:45:59.943466+00:00                <NA>
# 20867                              NaT                <NA>
# 23284                              NaT                <NA>
# 18817                              NaT                <NA>
#
#                     reimbursement_date cash_request_received_date  \
# 22228                              NaT                 2020-09-09
# 3885                               NaT                        NaT
# 20867                              NaT                 2020-10-28
# 23284 2020-11-16 14:04:48.442000+00:00                        NaT
# 18817                              NaT                 2020-10-28
#
#                        money_back_date transfer_type  \
# 22228 2020-11-05 00:43:28.826374+00:00       instant
# 3885                               NaT       instant
# 20867 2020-11-30 19:51:57.271978+00:00       instant
# 23284 2020-11-16 19:59:39.913772+00:00       instant
# 18817 2020-11-03 22:02:17.980741+00:00       instant
#
#                                send_at recovery_status  \
# 22228 2020-09-12 11:29:04.241975+00:00       completed
# 3885  2020-10-09 12:27:49.641000+00:00             NaN
# 20867 2020-10-27 10:18:06.134164+00:00             NaN
# 23284 2020-11-01 14:04:48.615076+00:00             NaN
# 18817 2020-10-27 19:47:40.610382+00:00             NaN
#
#                          reco_creation                 reco_last_update  \
# 22228 2020-11-03 22:29:34.916243+00:00 2020-11-05 00:43:28.846071+00:00
# 3885                               NaT                              NaT
# 20867                              NaT                              NaT
# 23284                              NaT                              NaT
# 18817                              NaT                              NaT
#
#        any_user_id
# 22228        37283
# 3885         12328
# 20867        33543
# 23284        37278
# 18817        95740

# %%
df_dict['cash request']['any_user_id'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Cash request - identify the cohorts

# %%
df_dict['cash request']['any_user_id'].nunique()

# total number of unique users
# Out:
# 11793

# %%
cohort_df = df_dict['cash request'] \
    .groupby('any_user_id') \
    .agg({'created_at' : 'min'}) \
    .sort_values('created_at')

# %%
cohort_df.shape
# Out:
# (11793, 1)

# %%
cohort_df.head()
# Out:
#                                   created_at
# any_user_id
# 47          2019-11-19 13:57:53.511561+00:00
# 1309        2019-12-09 14:47:35.190714+00:00
# 804         2019-12-10 19:05:21.596873+00:00
# 812         2019-12-10 19:05:48.921042+00:00
# 191         2019-12-10 19:13:35.825460+00:00

# %%
cohort_df = cohort_df \
    .assign(cohort = cohort_df['created_at'].dt.to_period('M')) \
    .drop(columns = 'created_at') \
    .reset_index()
# Out:
# /var/folders/jz/0vythxt91879l4fs8bggj2zw0000gn/T/ipykernel_24024/3268727358.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   .assign(cohort = cohort_df['created_at'].dt.to_period('M')) \

# %%
cohort_df.head()
# Out:
#    any_user_id   cohort
# 0           47  2019-11
# 1         1309  2019-12
# 2          804  2019-12
# 3          812  2019-12
# 4          191  2019-12

# %% [markdown]
# ## Cohort Intel

# %%
cohort_df_uu = cohort_df \
    .groupby('cohort') \
    .agg({'any_user_id' : 'count'}) \
    .reset_index() \

# unique user count by cohort (cohort df contains unique values only)

# %%
cohort_df_uu
# Out:
#      cohort  any_user_id
# 0   2019-11            1
# 1   2019-12          254
# 2   2020-01          106
# 3   2020-02           90
# 4   2020-03           86
# 5   2020-04          246
# 6   2020-05          432
# 7   2020-06         1540
# 8   2020-07         1482
# 9   2020-08          728
# 10  2020-09         1950
# 11  2020-10         4802
# 12  2020-11           76

# %%
cohort_df_uu.sort_values('cohort', ascending=False, inplace=True)

cohort_df_uu.plot.barh(
    x='cohort' , 
    y='any_user_id',
    title = 'User Count by Cohort',
    legend=False,
    xlabel='Count')

plt.show()

# %%
# add cohort column to cash_request

df_dict['cash request'] = pd.merge(
    left=df_dict['cash request'],
    right=cohort_df,
    on='any_user_id',
    how='left'
)

# %%
# transaction count per cohort

cohort_tr_count = df_dict['cash request'] \
    .value_counts('cohort') \
    .to_frame() \
    .sort_index() \
    .reset_index()

# %%
cohort_tr_count
# Out:
#      cohort  count
# 0   2019-11      8
# 1   2019-12   1080
# 2   2020-01    354
# 3   2020-02    441
# 4   2020-03    371
# 5   2020-04    952
# 6   2020-05   1660
# 7   2020-06   5266
# 8   2020-07   4147
# 9   2020-08   1632
# 10  2020-09   2925
# 11  2020-10   5058
# 12  2020-11     76

# %%
cohort_avg_tr_pu = pd.merge(
    left=cohort_tr_count,
    right=cohort_df_uu,
    on='cohort',
    how='inner'
).rename(columns = {'count' : 'Transactions', 'any_user_id' : 'Users'})

cohort_avg_tr_pu = cohort_avg_tr_pu \
    .sort_values('cohort') \
    .assign(
        avg_tr_pu = round(cohort_avg_tr_pu['Transactions'] / cohort_avg_tr_pu['Users'], 2))

cohort_avg_tr_pu = cohort_avg_tr_pu.rename(columns={
    'cohort': 'Cohort',
    'avg_tr_pu': 'AVG Transactions / User'
})

cohort_avg_tr_pu
# Out:
#      Cohort  Transactions  Users  AVG Transactions / User
# 0   2019-11             8      1                      8.0
# 1   2019-12          1080    254                     4.25
# 2   2020-01           354    106                     3.34
# 3   2020-02           441     90                      4.9
# 4   2020-03           371     86                     4.31
# 5   2020-04           952    246                     3.87
# 6   2020-05          1660    432                     3.84
# 7   2020-06          5266   1540                     3.42
# 8   2020-07          4147   1482                      2.8
# 9   2020-08          1632    728                     2.24
# 10  2020-09          2925   1950                      1.5
# 11  2020-10          5058   4802                     1.05
# 12  2020-11            76     76                      1.0

# %%
cohort_tr_count.sort_values('cohort', ascending=False, inplace=True)  

cohort_tr_count.plot.barh(
        x='cohort', 
        y='count',
        title='Cohort Transaction Count',
        xlabel='Count',
        legend=False);

# %%
# requests per user per cohort (overall count)
user_request_counts = df_dict['cash request'] \
    .groupby(['any_user_id', 'cohort']) \
    .size() \
    .reset_index(name='request_count')

# keep repeat users
repeat_users = user_request_counts.query('request_count > 1')

# count repeat users per cohort
repeat_users_per_cohort = repeat_users['cohort'].value_counts().sort_index()

repeat_users_per_cohort.plot.bar(
    title='Repeated Users per Cohort',
    xlabel='Cohort',
    ylabel='Users with > 1 request',
    rot=45
)
# Out:
# <Axes: title={'center': 'Repeated Users per Cohort'}, xlabel='Cohort', ylabel='Users with > 1 request'>

# %%
# months where users had > 2 requests

# all users with more than 2 requests in total 
users_3plus = user_request_counts.query('request_count > 2')['any_user_id']

# how many of those requests happened in each month
months_3plus = df_dict['cash request'] \
    .loc[df_dict['cash request']['any_user_id'].isin(users_3plus), 'created_at'] \
    .dt.to_period('M') \
    .value_counts() \
    .sort_index()

months_3plus.plot.bar(
    title='More than 2 requests',
    xlabel='Month',
    ylabel='users who have 2+ requests overall',
    rot=60
)
plt.show()
# Out:
# /var/folders/jz/0vythxt91879l4fs8bggj2zw0000gn/T/ipykernel_24024/3531337793.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   .dt.to_period('M') \

# %%
def heavy_users_per_month(df_cash, min_requests=3):
    # users with >= min_requests overall
    user_counts = df_cash.groupby('any_user_id').size()
    heavy_users = user_counts[user_counts >= min_requests].index

    # count unique heavy users per month
    return (
        df_cash.loc[df_cash['any_user_id'].isin(heavy_users)]
        .assign(month=df_cash['created_at'].dt.to_period('M'))
        .groupby('month')['any_user_id']
        .nunique()
        .sort_index()
    )

# usage
heavy_by_month = heavy_users_per_month(df_dict['cash request'], min_requests=3)
heavy_by_month.plot(
    title='Heavy Users per Month (>=3 requests total)',
    xlabel='Month',
    ylabel='Unique heavy users'
)
plt.show()
# Out:
# /var/folders/jz/0vythxt91879l4fs8bggj2zw0000gn/T/ipykernel_24024/3077528775.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   .assign(month=df_cash['created_at'].dt.to_period('M'))

# %%
# transaction count per month

tr_count_month = df_dict['cash request'] \
    .groupby(df_dict['cash request']['created_at'].dt.to_period('M')) \
    .agg({'id' : 'count'}) \
    .reset_index()
# Out:
# /var/folders/jz/0vythxt91879l4fs8bggj2zw0000gn/T/ipykernel_24024/500815559.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   .groupby(df_dict['cash request']['created_at'].dt.to_period('M')) \

# %%
tr_count_month
# Out:
#    created_at    id
# 0     2019-11     1
# 1     2019-12   289
# 2     2020-01   223
# 3     2020-02   184
# 4     2020-03   244
# 5     2020-04   473
# 6     2020-05   837
# 7     2020-06  2615
# 8     2020-07  3601
# 9     2020-08  3417
# 10    2020-09  4221
# 11    2020-10  7725
# 12    2020-11   140

# %%
tr_count_month.plot(
    x='created_at', 
    y='id',
    legend=False,
    title='Transaction Count per Month');

# %%
tr_growth_rate_month = tr_count_month \
    .assign(
        tr_growth_rate = (tr_count_month['id'] - tr_count_month['id'].shift(1)) / tr_count_month['id'].shift(1)
    )

# %%
tr_growth_rate_month
# Out:
#    created_at    id  tr_growth_rate
# 0     2019-11     1            <NA>
# 1     2019-12   289           288.0
# 2     2020-01   223       -0.228374
# 3     2020-02   184       -0.174888
# 4     2020-03   244        0.326087
# 5     2020-04   473        0.938525
# 6     2020-05   837        0.769556
# 7     2020-06  2615        2.124253
# 8     2020-07  3601        0.377055
# 9     2020-08  3417       -0.051097
# 10    2020-09  4221        0.235294
# 11    2020-10  7725        0.830135
# 12    2020-11   140       -0.981877

# %%
sns.heatmap(
    tr_growth_rate_month[['tr_growth_rate', 'created_at',]].set_index('created_at').query('created_at.between("2020-01", "2020-10")'),
    annot=True,
    cmap='coolwarm',
    vmin=-1,
    vmax=2.1
)

plt.title("Transaction Growth Rate per Month");

# %% [markdown]
# ## Fees exploration

# %%
df_dict['fees'].sample(3)
# Out:
#           id  cash_request_id             type     status category  \
# 17574   5915          13870.0         postpone  cancelled      NaN
# 7539   19678          26046.0  instant_payment   accepted      NaN
# 3599    9165          17604.0         postpone   accepted      NaN
#
#        total_amount                              reason  \
# 17574           5.0         Postpone Cash Request 13870
# 7539            5.0  Instant Payment Cash Request 26046
# 3599            5.0         Postpone Cash Request 17604
#
#                           created_at                     updated_at  \
# 17574  2020-09-03 18:39:58.094468+00  2020-10-13 14:25:17.554261+00
# 7539   2020-10-29 11:19:11.228322+00  2020-10-29 11:19:11.228345+00
# 3599   2020-09-25 06:49:11.074602+00   2020-10-13 14:25:13.73826+00
#
#                              paid_at               from_date  \
# 17574                            NaN  2020-09-11 10:00:00+00
# 7539   2020-11-05 20:57:44.179516+00                     NaN
# 3599   2020-09-25 06:49:14.764029+00  2020-11-04 11:00:00+00
#
#                       to_date charge_moment
# 17574  2020-10-11 10:00:00+00         after
# 7539                      NaN         after
# 3599   2020-12-04 11:00:00+00        before

# %%
print(df_dict['fees'].duplicated().sum())
print()
for col in ['id', 'cash_request_id']:
    print(f'{col}: {df_dict['fees'][col].duplicated().sum()}')
# Out:
# 0
#
# id: 0
# cash_request_id: 8127

# %%
df_dict['fees'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21061 non-null  int64
#  1   cash_request_id  21057 non-null  float64
#  2   type             21061 non-null  object
#  3   status           21061 non-null  object
#  4   category         2196 non-null   object
#  5   total_amount     21061 non-null  float64
#  6   reason           21061 non-null  object
#  7   created_at       21061 non-null  object
#  8   updated_at       21061 non-null  object
#  9   paid_at          15531 non-null  object
#  10  from_date        7766 non-null   object
#  11  to_date          7766 non-null   object
#  12  charge_moment    21061 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
df_dict['fees']['status'].unique()

# accpeted - payments to calculate the revenue
# confirmed - not an incident but also not revenue
# cancalled & rejected - incidents
# Out:
# array(['rejected', 'accepted', 'cancelled', 'confirmed'], dtype=object)

# %%
df_dict['fees'].isna().sum()
# Out:
# id                     0
# cash_request_id        4
# type                   0
# status                 0
# category           18865
# total_amount           0
# reason                 0
# created_at             0
# updated_at             0
# paid_at             5530
# from_date          13295
# to_date            13295
# charge_moment          0
# dtype: int64

# %%
df_dict['fees']['type'].unique()

# use type column to identify incidents, always filled in
# Out:
# array(['instant_payment', 'incident', 'postpone'], dtype=object)

# %%
# Notes
# sum the amounts for accepted transactions to get total revenue.
# incident if status in fees == rejected or cancelled

# %%
sns.histplot(df_dict['fees']['total_amount']);

# mostly 5 euro fees

# %%
df_dict['fees']['status'].value_counts()
# Out:
# status
# accepted     14841
# cancelled     4938
# rejected      1194
# confirmed       88
# Name: count, dtype: int64

# %% [markdown]
# ## Fees Data Cleaning

# %%
df_dict['fees'].columns
# Out:
# Index(['id', 'cash_request_id', 'type', 'status', 'category', 'total_amount',
#        'reason', 'created_at', 'updated_at', 'paid_at', 'from_date', 'to_date',
#        'charge_moment'],
#       dtype='object')

# %%
for col in ['created_at', 'updated_at', 'paid_at', 'from_date', 'to_date']:
    df_dict['fees'][col] = pd.to_datetime(df_dict['fees'][col], errors='coerce')

# %%
df_dict['fees'].dtypes
# Out:
# id                               int64
# cash_request_id                float64
# type                            object
# status                          object
# category                        object
# total_amount                   float64
# reason                          object
# created_at         datetime64[ns, UTC]
# updated_at         datetime64[ns, UTC]
# paid_at            datetime64[ns, UTC]
# from_date          datetime64[ns, UTC]
# to_date            datetime64[ns, UTC]
# charge_moment                   object
# dtype: object

# %%
df_dict['fees']['cash_request_id'] = df_dict['fees']['cash_request_id'].astype('Int64')

# %% [markdown]
# ## Merge fees and part of the cash request

# %%
df_dict['fees'].head(3)
# Out:
#       id  cash_request_id             type    status               category  \
# 0   6537            14941  instant_payment  rejected                    NaN
# 1   6961            11714         incident  accepted  rejected_direct_debit
# 2  16296            23371  instant_payment  accepted                    NaN
#
#    total_amount                              reason  \
# 0           5.0  Instant Payment Cash Request 14941
# 1           5.0               rejected direct debit
# 2           5.0  Instant Payment Cash Request 23371
#
#                         created_at                       updated_at  \
# 0 2020-09-07 10:47:27.423150+00:00 2020-10-13 14:25:09.396112+00:00
# 1 2020-09-09 20:51:17.998653+00:00 2020-10-13 14:25:15.537063+00:00
# 2 2020-10-23 10:10:58.352972+00:00 2020-10-23 10:10:58.352994+00:00
#
#                            paid_at from_date to_date charge_moment
# 0 2020-12-17 14:50:07.470110+00:00       NaT     NaT         after
# 1 2020-12-08 17:13:10.459080+00:00       NaT     NaT         after
# 2 2020-11-04 19:34:37.432910+00:00       NaT     NaT         after

# %%
df_dict['cash request'][['id', 'cohort']]
# Out:
#           id   cohort
# 0          5  2019-12
# 1         70  2019-12
# 2          7  2019-12
# 3         10  2019-12
# 4       1594  2020-05
# ...      ...      ...
# 23965  20616  2020-06
# 23966  25243  2020-10
# 23967  22357  2020-10
# 23968  20256  2020-10
# 23969  19886  2020-09
#
# [23970 rows x 2 columns]

# %%
fees_by_cohort = pd.merge(
    left = df_dict['fees'],
    right = df_dict['cash request'][['id', 'cohort']],
    left_on = 'cash_request_id',
    right_on = 'id',
    how = 'left'
) \
    .drop(columns = ['id_y']) \
    .rename(columns = {'id_x' : 'id'})

# %%
fees_by_cohort.head(3)
# Out:
#       id  cash_request_id             type    status               category  \
# 0   6537            14941  instant_payment  rejected                    NaN
# 1   6961            11714         incident  accepted  rejected_direct_debit
# 2  16296            23371  instant_payment  accepted                    NaN
#
#    total_amount                              reason  \
# 0           5.0  Instant Payment Cash Request 14941
# 1           5.0               rejected direct debit
# 2           5.0  Instant Payment Cash Request 23371
#
#                         created_at                       updated_at  \
# 0 2020-09-07 10:47:27.423150+00:00 2020-10-13 14:25:09.396112+00:00
# 1 2020-09-09 20:51:17.998653+00:00 2020-10-13 14:25:15.537063+00:00
# 2 2020-10-23 10:10:58.352972+00:00 2020-10-23 10:10:58.352994+00:00
#
#                            paid_at from_date to_date charge_moment   cohort
# 0 2020-12-17 14:50:07.470110+00:00       NaT     NaT         after  2020-09
# 1 2020-12-08 17:13:10.459080+00:00       NaT     NaT         after  2020-06
# 2 2020-11-04 19:34:37.432910+00:00       NaT     NaT         after  2020-10

# %% [markdown]
# ## Revenue

# %%
revenue_df = \
    fees_by_cohort \
        .query('status == "accepted"')

# %%
revenue_df \
    .groupby('cohort') \
    .agg({'total_amount' : 'sum'}) \
    .plot.barh(
        legend=False,
        title='Revenue by Cohort');

# %%
revenue_df \
    .groupby('cohort') \
    .agg({'total_amount' : 'sum'}) \
    .plot.bar(
        legend=False,
        title='Revenue by Cohort',
        rot=45);

# %%
revenue_df.isna().sum()

# paid at is missing in 396 cases
# Out:
# id                     0
# cash_request_id        0
# type                   0
# status                 0
# category           13281
# total_amount           0
# reason                 0
# created_at             0
# updated_at             0
# paid_at              396
# from_date          12288
# to_date            12329
# charge_moment          0
# cohort                 0
# dtype: int64

# %%
avg_time_to_pay = (revenue_df['paid_at'] - revenue_df['created_at']).mean()
avg_time_to_pay
# Out:
# Timedelta('24 days 11:02:15.772419588')

# %%
revenue_df['paid_at'] = revenue_df['paid_at'].fillna(revenue_df['created_at'] + avg_time_to_pay)

# fill in paid at missing values with avg time to pay
# Out:
# /var/folders/jz/0vythxt91879l4fs8bggj2zw0000gn/T/ipykernel_24024/3983987446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   revenue_df['paid_at'] = revenue_df['paid_at'].fillna(revenue_df['created_at'] + avg_time_to_pay)

# %%
revenue_df.isna().sum()
# Out:
# id                     0
# cash_request_id        0
# type                   0
# status                 0
# category           13281
# total_amount           0
# reason                 0
# created_at             0
# updated_at             0
# paid_at                0
# from_date          12288
# to_date            12329
# charge_moment          0
# cohort                 0
# dtype: int64

# %%
revenue_df \
    .groupby(revenue_df['paid_at'].dt.to_period('M')) \
    .agg({'total_amount' : 'sum'}) \
    .sort_index() \
    .plot(
        legend=False,
        title='Revenue by Month',
        ylabel='Revenue'
    );
# Out:
# /var/folders/jz/0vythxt91879l4fs8bggj2zw0000gn/T/ipykernel_24024/1621793852.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   .groupby(revenue_df['paid_at'].dt.to_period('M')) \

# %%
fees_by_cohort['status'].unique()
# Out:
# array(['rejected', 'accepted', 'cancelled', 'confirmed'], dtype=object)

# %%
incidents_per_cohort = fees_by_cohort \
    .query('status in ["rejected", "cancelled"]') \
    .groupby('cohort') \
    .agg({'status' : 'count'}) \
    .reset_index() \
    .rename(columns = {'status' : 'incidents_count'})

# %%
incidents_per_cohort
# Out:
#      cohort  incidents_count
# 0   2019-11                4
# 1   2019-12               84
# 2   2020-01               39
# 3   2020-02               65
# 4   2020-03               44
# 5   2020-04              196
# 6   2020-05              396
# 7   2020-06             1605
# 8   2020-07             1195
# 9   2020-08              409
# 10  2020-09              938
# 11  2020-10             1150
# 12  2020-11                3

# %%
fees_attemps = fees_by_cohort \
    .groupby('cohort') \
    .agg({'status' : 'count'}) \
    .reset_index() \
    .rename(columns = {'status' : 'fees_attemps_count'})

# %%
incident_rate = pd.merge(
    left=fees_attemps,
    right=incidents_per_cohort,
    on='cohort',
    how='left'
)

incident_rate = incident_rate.assign(
    incident_rate = incident_rate['incidents_count'] / incident_rate['fees_attemps_count']
)

# %%
incident_rate
# Out:
#      cohort  fees_attemps_count  incidents_count  incident_rate
# 0   2019-11                  10                4       0.400000
# 1   2019-12                 311               84       0.270096
# 2   2020-01                 131               39       0.297710
# 3   2020-02                 193               65       0.336788
# 4   2020-03                 174               44       0.252874
# 5   2020-04                 513              196       0.382066
# 6   2020-05                1186              396       0.333895
# 7   2020-06                4499             1605       0.356746
# 8   2020-07                3435             1195       0.347889
# 9   2020-08                1419              409       0.288231
# 10  2020-09                3220              938       0.291304
# 11  2020-10                5899             1150       0.194948
# 12  2020-11                  67                3       0.044776

# %%
sns.heatmap(
    incident_rate[['cohort', 'incident_rate']].set_index('cohort'),
    annot=True,
    fmt='g',
    cmap='coolwarm',
    vmin=0,
    vmax=0.4
)

plt.title('Incident Rate by Cohort');
